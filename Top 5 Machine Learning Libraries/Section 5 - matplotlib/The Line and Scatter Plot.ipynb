# %%
# Importing the matplotlib and numpy

import matplotlib.pyplot as plt
import numpy as np

# %%
# Let's add some data

x = np.linspace(0,10,100)

# %%
# Let's plot it

plt.plot(x,x, label = 'Linear')
plt.legend()
plt.show()

# %%
# Let's create a scatterplot

X = [1,2,3,4,5,6,7,8,9]
Y = [1,2,3,4,5,6,7,8,9]
plt.scatter(X,Y)
plt.show()
